# %% [markdown]
# <a href="https://colab.research.google.com/github/mgarbanzo/PercepcionRemota/blob/main/PRI_Actividad_did%C3%A1ctica_1_Ondas_cuadradas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Curso: Percepción Remota I
#
# Profesor: Marcial Garbanzo Salas
#
# Semestre: II-2021

# %% [markdown]
# # SUMAS DE FOURIER
#
# Enunciado: Obtenga una onda cuadrada a partir de la suma de sus componentes de Fourier y obtenga el error de la aproximación como función del número de términos utilizados

# %%
import numpy as np
import pylab as plt
from scipy import signal

# %%
def CalculaSumaFourier(n):
  aprox = np.zeros_like(t)
  for N in range(1,2*n+1,2):
    Napprox = (1/N) * np.sin(N*w*t)
    aprox = aprox + Napprox
  aprox = 4/np.pi * aprox
  return aprox

# %%
def CalculaError(y1,y2):
  return np.sum(np.abs(y1-y2))

# %%
T = 10 #s
w = 2 * np.pi / T

# %%
t = np.arange(0,100,0.1)
cuadrada = signal.square(w*t)

# %%
n = 3

# %%
aprox = CalculaSumaFourier(n)

# %%
plt.figure()
plt.plot(t, aprox, '-r')
plt.plot(t, cuadrada, '-k')

# %%
plt.plot(t, np.abs(cuadrada - aprox))

# %%
Error = np.sum(np.abs(cuadrada - aprox))
print(Error)
# Out:
# 31.131266937167926

# %% [markdown]
# # Calculando el comportamiento del error

# %%
Errores = []
for n in range(1,500):
  Errores.append(CalculaError(cuadrada,CalculaSumaFourier(n)))

# %%
plt.plot(Errores)

# %%
plt.plot(np.log(Errores))

# %%
plt.plot(np.gradient(Errores))

# %% [markdown]
# # Veamos las componentes de Fourier:

# %%
FFTcuadrada = np.fft.fft(cuadrada)
FFTaprox = np.fft.fft(aprox)

# %%
plt.figure()
plt.plot(FFTcuadrada)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure()
plt.plot(np.imag(FFTcuadrada))

# %%
plt.figure()
plt.plot(np.abs(FFTcuadrada))

# %%
XFT = np.fft.fftfreq(len(FFTcuadrada),d=0.1)

# %%
plt.figure()
plt.plot(XFT, np.abs(FFTcuadrada))
#plt.plot(XFT, np.abs(FFTaprox))
